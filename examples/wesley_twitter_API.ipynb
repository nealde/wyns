# %% [markdown]
# # Notes on using python-twitter for direct capstone
#
# first pip install python-twitter: `pip install python-twitter`
#
# if you want, [readthedocs](https://python-twitter.readthedocs.io/en/latest/installation.html)
#
# then setup a twitter app. I followed these [instructions](https://iag.me/socialmedia/how-to-create-a-twitter-app-in-8-easy-steps/)
#
# The site seems to have changed a bit since that post but, more or less the same.
#
# The important thing is to obtain your consumer key/secret and access key/secret.
#
# You would instantiate them with twitter with the following:

# %%
import twitter

# %%
api=twitter.Api(consumer_key="",
consumer_secret="",
access_token_key="",
access_token_secret="")

# %% [markdown]
# You can then run things like:

# %%
users = api.GetFriends()
print([u.screen_name for u in users])
# Out:
# ['QuantaMagazine', 'gar3t', 'nicoleperlroth', 'RepJayapal', 'HowIBuiltThis', 'VirgiC12', 'KaluYala', 'Prison2Perfect', 'PlanetFitness', 'muscle_fitness', 'Bodybuildingcom', 'GoldsGym', 'BishopGormanFB', 'alyssalynn7', 'TheTateMartell', 'queenpsays', 'numichuu', 'neeeelshah', 'JustinRoiland', 'danharmon', 'RickandMorty', 'nakedcitybeer', 'fremontbrewing', 'ChairmanGao', 'abheerama', 'kelseyjocorey', 'arushiuw', 'BigTimeBrewery', 'jradavenport', 'github', 'DJsnowhite', 'verychristopher', 'Twitter', 'thewhitepanda']

# %% [markdown]
# Or, potentially very *neat* we can load up samples of live tweets:

# %%
for line in api.GetStreamSample():
    print(json.dumps(line))
# Out:
# {"created_at": "Fri May 04 20:51:36 +0000 2018", "id": 992507055855620097, "id_str": "992507055855620097", "text": "@ksauds37 \u0628\u0645\u0646\u0627\u0633\u0628\u0629 \u062f\u062e\u0648\u0644 \u0627\u0644\u0627\u062e\u062a\u0628\u0627\u0631\u0627\u062a \u0627\u0644\u0646\u0647\u0627\u0626\u064a\u0629 \u0641\u064a \u0627\u0644\u0641\u0635\u0644 \u0627\u0644\u062b\u0627\u0646\u064a 1438/1439\u0647\u0640 \u0641\u0625\u0646\u064a \u0623\u0630\u0643\u0631 \u0623\u0648\u0644\u064a\u0627\u0621 \u0627\u0644\u0623\u0645\u0648\u0631 \u0628\u0640\u0640 https://t.co/o8n4NP6Zf9", "display_text_range": [0, 98], "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": 4067025334, "in_reply_to_user_id_str": "4067025334", "in_reply_to_screen_name": "ksauds37", "user": {"id": 862874930, "id_str": "862874930", "name": "\u062e\u0627\u0644\u062f \u0627\u0644\u0644\u062d\u064a\u0627\u0646\u064a", "screen_name": "KhaledaishN", "location": "\u0645\u0646\u0637\u0642\u0629 \u0645\u0643\u0629 \u0627\u0644\u0645\u0643\u0631\u0645\u0629 \u0640\u0640\u0640 \u0627\u0644\u0637\u0627\u0626\u0641 .", "url": null, "description": "\u0645\u0627\u062c\u0633\u062a\u064a\u0631 \u0639\u0642\u064a\u062f\u0629 \u0645\u0646 \u0627\u0644\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u0625\u0633\u0644\u0627\u0645\u064a\u0629 \u0628\u0627\u0644\u0645\u062f\u064a\u0646\u0629 \u0627\u0644\u0646\u0628\u0648\u064a\u0629 .  \u0640\u0640\u0640 \u0623\u062d\u0636\u0631 \u0644\u0644\u062f\u0643\u062a\u0648\u0631\u0627\u0629 \u0641\u064a \u0627\u0644\u0639\u0642\u064a\u062f\u0629 \u0645\u0646 \u0627\u0644\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u0625\u0633\u0644\u0627\u0645\u064a\u0629 .", "translator_type": "none", "protected": false, "verified": false, "followers_count": 9, "friends_count": 14, "listed_count": 0, "favourites_count": 3, "statuses_count": 59, "created_at": "Fri Oct 05 11:07:10 +0000 2012", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "ar", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/611299143500169216/l8kkQQYC_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/611299143500169216/l8kkQQYC_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/862874930/1435060667", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [{"screen_name": "ksauds37", "name": "\u062b\u0627\u0646\u0648\u064a\u0629 \u0627\u0644\u0645\u0644\u0643 \u0633\u0639\u0648\u062f", "id": 4067025334, "id_str": "4067025334", "indices": [0, 9]}], "symbols": [], "media": [{"id": 992506916864692225, "id_str": "992506916864692225", "indices": [99, 122], "media_url": "http://pbs.twimg.com/media/DcYXyEjWkAEDT4Y.jpg", "media_url_https": "https://pbs.twimg.com/media/DcYXyEjWkAEDT4Y.jpg", "url": "https://t.co/o8n4NP6Zf9", "display_url": "pic.twitter.com/o8n4NP6Zf9", "expanded_url": "https://twitter.com/KhaledaishN/status/992507055855620097/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "small": {"w": 383, "h": 680, "resize": "fit"}, "large": {"w": 720, "h": 1280, "resize": "fi ...
# {"delete": {"status": {"id": 921039777331232768, "id_str": "921039777331232768", "user_id": 3110777579, "user_id_str": "3110777579"}, "timestamp_ms": "1525467097341"}}
# {"delete": {"status": {"id": 742375928374960128, "id_str": "742375928374960128", "user_id": 2223188931, "user_id_str": "2223188931"}, "timestamp_ms": "1525467097368"}}
# {"delete": {"status": {"id": 620775920916271104, "id_str": "620775920916271104", "user_id": 158551881, "user_id_str": "158551881"}, "timestamp_ms": "1525467097467"}}
# {"delete": {"status": {"id": 984238493021982720, "id_str": "984238493021982720", "user_id": 2957355216, "user_id_str": "2957355216"}, "timestamp_ms": "1525467097467"}}
# {"delete": {"status": {"id": 620778131327188992, "id_str": "620778131327188992", "user_id": 101274602, "user_id_str": "101274602"}, "timestamp_ms": "1525467097565"}}
# {"delete": {"status": {"id": 989370307852013569, "id_str": "989370307852013569", "user_id": 2219432903, "user_id_str": "2219432903"}, "timestamp_ms": "1525467097594"}}
# {"delete": {"status": {"id": 620780274612346882, "id_str": "620780274612346882", "user_id": 326147915, "user_id_str": "326147915"}, "timestamp_ms": "1525467097677"}}
# {"delete": {"status": {"id": 687789993654358019, "id_str": "687789993654358019", "user_id": 153109879, "user_id_str": "153109879"}, "timestamp_ms": "1525467097690"}}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060032950272, "id_str": "992507060032950272", "text": "RT @BALXCKO2: \u253b \ud83d\udd25\ud80d\udc20  \ud80c\ude5a \u0432 \u03b1 \u2113 \u1d0f \u1d04 \u04c4 \ud80c\ude5c  \ud80d\udc20 \ud83d\udd25\u263c \u2533 \n                      \ud83d\udeac\ud83d\udcaf\n\n\u16d9 \u2316 \u2580  \ud80c\udf16 \ud80c\udfe4 \ud80c\ude58 @BALXCKO2 \ud80c\ude5d \ud80c\udfe4 \ud80c\udf16 \u2580 \u2316 \u16d9\n    \u2571 \u2701\u26d3 \u2592 \u253b PCY.1992 \u2533 \u2592\u26d3 \u2571 http\u2026", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 992008805499133954, "id_str": "992008805499133954", "name": "\u0e0b\u0e2d\u0e1f\u0e15\u0e4c\u0e40\u0e23\u0e34\u0e49\u0e1b\u0e27\u0e34\u0e0a\u0e31\u0e48\u0e19 SUPERSPC", "screen_name": "softavengersx20", "location": null, "url": null, "description": "By @hyeongsoft @SoftAvengersFF", "translator_type": "none", "protected": false, "verified": false, "followers_count": 1, "friends_count": 6, "listed_count": 0, "favourites_count": 0, "statuses_count": 1, "created_at": "Thu May 03 11:51:44 +0000 2018", "utc_offset": -25200, "time_zone": "Pacific Time (US & Canada)", "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/992451070159802368/C6ClBSRB_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/992451070159802368/C6ClBSRB_normal.jpg", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 18:49:14 +0000 2018", "id": 992476260847599617, "id_str": "992476260847599617", "text": "\u253b \ud83d\udd25\ud80d\udc20  \ud80c\ude5a \u0432 \u03b1 \u2113 \u1d0f \u1d04 \u04c4 \ud80c\ude5c  \ud80d\udc20 \ud83d\udd25\u263c \u2533 \n                      \ud83d\udeac\ud83d\udcaf\n\n\u16d9 \u2316 \u2580  \ud80c\udf16 \ud80c\udfe4 \ud80c\ude58 @BALXCKO2 \ud80c\ude5d \ud80c\udfe4 \ud80c\udf16 \u2580 \u2316 \u16d9\n    \u2571 \u2701\u26d3 \u2592 \u253b PCY.1992 \u2533\u2026 https://t.co/yE3RyRqR6y", "display_text_range": [0, 140], "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": true, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 777927189110992896, "id_str": "777927189110992896", "name": "BALOCK\ud83d\udeac/rest", "screen_name": "BALXCKO2", "location": null, "url": null, "description": "\ud80c\udff6 KEEP CALM AND TOUCH MY BODY . ILY \u00b0\u205e\u2020 \ud80c\udff6", "translator_type": "none", "protected": false, "verified": false, "followers_count": 144, "friends_count": 51, "listed_count": 0, "favourites_count": 478, "statuses_count": 4615, "created_at": "Mon Sep 19 17:47:50 +0000 2016", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "th", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "33333 ...
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060062310400, "id_str": "992507060062310400", "text": "@effembee @MiaFarrow @SenJohnMcCain @LindseyGrahamSC They could be happy just to smash up the place, dig in, and launch attacks on Iran.", "display_text_range": [53, 136], "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": 992504670043230208, "in_reply_to_status_id_str": "992504670043230208", "in_reply_to_user_id": 129306386, "in_reply_to_user_id_str": "129306386", "in_reply_to_screen_name": "effembee", "user": {"id": 910119351537324032, "id_str": "910119351537324032", "name": "#StoicSupermensh", "screen_name": "InformedTakes", "location": "Earth", "url": "http://snopes.com", "description": "Used to be @peebsy0. Banned after Nazis mass reported an offensive tweet, in which I shared an Ari Gold gif from Twitters own library without comment.", "translator_type": "none", "protected": false, "verified": false, "followers_count": 498, "friends_count": 2458, "listed_count": 8, "favourites_count": 32811, "statuses_count": 45692, "created_at": "Tue Sep 19 12:32:17 +0000 2017", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/983762086873382912/8j0CtbBd_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/983762086873382912/8j0CtbBd_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/910119351537324032/1512747631", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [{"screen_name": "effembee", "name": "Megan Leora \ud83c\udf24 \u0645\u0627\u063a\u0646 \u0644\u064a\u0648\u0631\u0629", "id": 129306386, "id_str": "129306386", "indices": [0, 9]}, {"screen_name": "MiaFarrow", "name": "Mia Farrow", "id": 33235771, "id_str": "33235771", "indices": [10, 20]}, {"screen_name": "SenJohnMcCain", "name": "John McCain", "id": 19394188, "id_str": "19394188", "indices": [21, 35]}, {"screen_name": "LindseyGrahamSC", "name": "Lindsey Graham", "id": 432895323, "id_str": "432895323", "indices": [36, 52]}], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "en", "timestamp_ms": "1525467097665"}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060037206016, "id_str": "992507060037206016", "text": "RT @malepichot: La jueza lo trat\u00f3 en femenino, incumpliendo la ley y demostrando su transfobia. Por culpa de una jueza y un sistema machist\u2026", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 2468490086, "id_str": "2468490086", "name": "#NiUnaMenosSofia", "screen_name": "sofiagastellu", "location": null, "url": null, "description": "Docente Historia. CNBA y Pelle. De AGD. Retweets are not endorsements. P", "translator_type": "none", "protected": false, "verified": false, "followers_count": 459, "friends_count": 1774, "listed_count": 27, "favourites_count": 29888, "statuses_count": 18340, "created_at": "Tue Apr 29 00:56:10 +0000 2014", "utc_offset": -10800, "time_zone": "Santiago", "geo_enabled": false, "lang": "es", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "AA00B3", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/986762706614177793/_0KlA0JB_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/986762706614177793/_0KlA0JB_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/2468490086/1461269611", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 19:05:00 +0000 2018", "id": 992480230341332992, "id_str": "992480230341332992", "text": "La jueza lo trat\u00f3 en femenino, incumpliendo la ley y demostrando su transfobia. Por culpa de una jueza y un sistema\u2026 https://t.co/omQqZ8F4BN", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": true, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 85692592, "id_str": "85692592", "name": "malena pichot", "screen_name": "malepichot", "location": null, "url": "http://malenapichot.com", "description": "Guionista de Cualca, Jorge, Por ahora y Mundillo. ac\u00e1 https://www.youtube.com/malepichot y TARDE BABY ahora mismo disponible por @un3TV", "translator_type": "regular", "protected": false, "verified": true, "followers_count": 1259119, "friends_count": 1033, "listed_count": 2087, "favourites_count": 35516, "statuses_count": 37765, "created_at": "Tue Oct 27 23:34:59 +0000 2009", "utc_offset": -25200, "time_zone": "Pacific Time (US & Canada)", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F0E7E7", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/358356419/From_Me_To_You_copy.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/358356419/From_Me_To_You_copy.jpg", "profile_background_tile": true, "profile_link_color": "F24441", "profile_sidebar_border_color": "53777A", "profile_sidebar_fill_color": "B8E4F2", "profile_text_color": "141313", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/799295046365409280/FlZFBXE9_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/prof ...
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060028817408, "id_str": "992507060028817408", "text": "s/o to our boss for giving monday's off cause now we taking over six flags this monday", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 464926133, "id_str": "464926133", "name": "julisa", "screen_name": "HeyThereJulisa", "location": null, "url": null, "description": null, "translator_type": "none", "protected": false, "verified": false, "followers_count": 1296, "friends_count": 649, "listed_count": 5, "favourites_count": 45634, "statuses_count": 63675, "created_at": "Sun Jan 15 19:35:20 +0000 2012", "utc_offset": -36000, "time_zone": "Hawaii", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/692097096/da9d4b2addc97396fb621511b85c80f5.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/692097096/da9d4b2addc97396fb621511b85c80f5.jpeg", "profile_background_tile": true, "profile_link_color": "0084B4", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/984485583857729536/Usek-FZv_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/984485583857729536/Usek-FZv_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/464926133/1507495890", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "en", "timestamp_ms": "1525467097657"}
# {"delete": {"status": {"id": 992432002971222016, "id_str": "992432002971222016", "user_id": 2480502554, "user_id_str": "2480502554"}, "timestamp_ms": "1525467097784"}}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060041367552, "id_str": "992507060041367552", "text": "\u5317\u539f\u91cc\u82f1\u306e\u30c9\u30ad\u30e5\u30e1\u30f3\u30bf\u30ea\u30fc\uff01\u30c9\u30e9\u30de\u304c\u4eba\u6c17\uff01\u7dcf\u9078\u6319\u306b\u30ad\u30b9\u306e\u8a71\u984c\u3082\nhttps://t.co/gIAljiLnks \u2026\n\u5e78\u798f\u3078\u306e\u9053\u6a19", "source": "<a href=\"http://twittbot.net/\" rel=\"nofollow\">twittbot.net</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 2938068594, "id_str": "2938068594", "name": "\u30d3\u30e5\u30fc\u30c6\u30a3\u30a8\u30a4\u30c8", "screen_name": "hika_189", "location": null, "url": null, "description": null, "translator_type": "none", "protected": false, "verified": false, "followers_count": 7967, "friends_count": 8269, "listed_count": 3, "favourites_count": 9, "statuses_count": 37052, "created_at": "Sun Dec 21 11:43:07 +0000 2014", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "ja", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/546646806038183937/YoqkVI9P_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/546646806038183937/YoqkVI9P_normal.jpeg", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [{"url": "https://t.co/gIAljiLnks", "expanded_url": "http://genryu08.com/kitahararienodokyume-7691", "display_url": "genryu08.com/kitahararienod\u2026", "indices": [32, 55]}], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "possibly_sensitive": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1525467097660"}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060041474049, "id_str": "992507060041474049", "text": "RT @veklince: Erdo\u011fan\u2019\u0131n hi\u00e7bir zaman ba\u015faramayacag\u0131 bir \u015feyi yapaca\u011f\u0131m. \u0130lk mitingime 5 \u00fcniversite arkada\u015f\u0131mla birlikte \u00e7\u0131kaca\u011f\u0131m.", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 383355597, "id_str": "383355597", "name": "Atat\u00fcrk\u00e7\u00fc ve laik", "screen_name": "midilsh", "location": "istanbul", "url": null, "description": null, "translator_type": "none", "protected": false, "verified": false, "followers_count": 3980, "friends_count": 3860, "listed_count": 5, "favourites_count": 7377, "statuses_count": 8671, "created_at": "Sat Oct 01 18:44:38 +0000 2011", "utc_offset": 10800, "time_zone": "Istanbul", "geo_enabled": true, "lang": "tr", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/378800000534746082/65fcb383d2f0c9f6b3e94fac9ac64f58_normal.png", "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000534746082/65fcb383d2f0c9f6b3e94fac9ac64f58_normal.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/383355597/1378913847", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 17:22:39 +0000 2018", "id": 992454472940118016, "id_str": "992454472940118016", "text": "Erdo\u011fan\u2019\u0131n hi\u00e7bir zaman ba\u015faramayacag\u0131 bir \u015feyi yapaca\u011f\u0131m. \u0130lk mitingime 5 \u00fcniversite arkada\u015f\u0131mla birlikte \u00e7\u0131kaca\u011f\u0131m.", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 967036084470407169, "id_str": "967036084470407169", "name": "Muharrem \u0130NCE", "screen_name": "veklince", "location": null, "url": null, "description": "Tepeden t\u0131rna\u011fa cesaret... Her \u015fey T\u00fcrkiye\u2019yi sevmekten ibaret. Parodi fan hesap. Muharrem \u0130nce ba\u015fkan\u0131n ger\u00e7ek hesab\u0131 @vekilince\u2019dir", "translator_type": "none", "protected": false, "verified": false, "followers_count": 6373, "friends_count": 2, "listed_count": 7, "favourites_count": 108, "statuses_count": 47, "created_at": "Fri Feb 23 13:59:04 +0000 2018", "utc_offset": -25200, "time_zone": "Pacific Time (US & Canada)", "geo_enabled": false, "lang": "tr", "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1B95E0", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/99244392156016230 ...
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060058112000, "id_str": "992507060058112000", "text": "RT @Kyleraj13Kyle: @BicdNh Hehehehehe https://t.co/QNNlyuNZkJ", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 745731132138782721, "id_str": "745731132138782721", "name": "\u30e9\u30b8\u30aa", "screen_name": "BicdNh", "location": null, "url": null, "description": "\u51cd\u7d50\u3055\u308c\u307e\u3057\u305f\u30d2\u30f3\u30b1\u30eb\u3067\u3059\uff01 \u5b9c\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059\uff01\u300e\u30cd\u30c3\u30d5\u30a3\u30fc\u3055\u3093\u2113\u03c3\u03bd\u0454(o^^o)\u300f", "translator_type": "none", "protected": false, "verified": false, "followers_count": 299, "friends_count": 935, "listed_count": 3, "favourites_count": 5683, "statuses_count": 330, "created_at": "Wed Jun 22 21:32:11 +0000 2016", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/745743001985523713/TZl6Y2wE_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/745743001985523713/TZl6Y2wE_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/745731132138782721/1466633854", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 20:32:05 +0000 2018", "id": 992502144879267841, "id_str": "992502144879267841", "text": "@BicdNh Hehehehehe https://t.co/QNNlyuNZkJ", "display_text_range": [8, 18], "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": 992501989308186624, "in_reply_to_status_id_str": "992501989308186624", "in_reply_to_user_id": 745731132138782721, "in_reply_to_user_id_str": "745731132138782721", "in_reply_to_screen_name": "BicdNh", "user": {"id": 3666715762, "id_str": "3666715762", "name": "kyle jennings", "screen_name": "Kyleraj13Kyle", "location": null, "url": null, "description": "Love anime/manga/gamer/talker/an amateur drawer and I love anything to draw about Anime. please don't report just block me if you don't like me and DM me", "translator_type": "none", "protected": false, "verified": false, "followers_count": 286, "friends_count": 928, "listed_count": 1, "favourites_count": 8355, "statuses_count": 7645, "created_at": "Tue Sep 15 18:42:08 +0000 2015", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/897494873099653120/qBH8qBod_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/897494873099653120/qBH8qBod_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/3666715762/1496319567" ...
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060062306304, "id_str": "992507060062306304", "text": "RT @WTAE: Fan dies watching 'Avengers' after suspected heart attack https://t.co/8RKAKh8Hdd https://t.co/50dRxQJL6U", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 759269962859110400, "id_str": "759269962859110400", "name": "amanda", "screen_name": "boolamanda", "location": null, "url": null, "description": "17 \ud83d\udcda", "translator_type": "none", "protected": false, "verified": false, "followers_count": 341, "friends_count": 332, "listed_count": 0, "favourites_count": 2923, "statuses_count": 1931, "created_at": "Sat Jul 30 06:10:40 +0000 2016", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/980887744757968896/UxwDTcYD_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/980887744757968896/UxwDTcYD_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/759269962859110400/1525108863", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Wed May 02 21:44:04 +0000 2018", "id": 991795485043130368, "id_str": "991795485043130368", "text": "Fan dies watching 'Avengers' after suspected heart attack https://t.co/8RKAKh8Hdd https://t.co/50dRxQJL6U", "display_text_range": [0, 81], "source": "<a href=\"https://dlvrit.com/\" rel=\"nofollow\">dlvr.it</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 15168829, "id_str": "15168829", "name": "WTAE-TV Pittsburgh", "screen_name": "WTAE", "location": "Pittsburgh, Pennsylvania, USA", "url": "http://www.WTAE.com", "description": "Pittsburgh's news, weather & sports! #WTAE", "translator_type": "none", "protected": false, "verified": true, "followers_count": 120740, "friends_count": 1415, "listed_count": 1234, "favourites_count": 953, "statuses_count": 232434, "created_at": "Thu Jun 19 12:46:59 +0000 2008", "utc_offset": -14400, "time_zone": "Eastern Time (US & Canada)", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "07237A", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/465972576737443840/SxFFaf-7.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/465972576737443840/SxFFaf-7.jpeg", "profile_background_tile": false, "profile_link_color": "1B0FFF", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "CAD6D8", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/458965771817721856/cKpYWO_N_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/458965771817721856/cKpYWO_N_normal.jpeg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/15168829/1481205700", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": n ...
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060066701312, "id_str": "992507060066701312", "text": "Steven Gerrard, Cattleshow and bank holiday Monday. \ud83d\ude0e", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 22165524, "id_str": "22165524", "name": "Ross", "screen_name": "swin182", "location": "Glasgow, Scotland", "url": null, "description": "25. Have a love affair with Rangers, Strawberry Daiquiris and Coco Pops", "translator_type": "none", "protected": false, "verified": false, "followers_count": 231, "friends_count": 248, "listed_count": 1, "favourites_count": 1379, "statuses_count": 2981, "created_at": "Fri Feb 27 17:41:20 +0000 2009", "utc_offset": 3600, "time_zone": "Edinburgh", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/808813153886806016/Bc0Qk3s6_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/808813153886806016/Bc0Qk3s6_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/22165524/1424389045", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "en", "timestamp_ms": "1525467097666"}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060066574336, "id_str": "992507060066574336", "text": "\u7121\u4eba\u5cf6\u306b\u5973\u3060\u3051\u3067\u30b5\u30d0\u30a4\u30d0\u30eb\u751f\u6d3b\u3092\u3059\u308b\u3068\u3069\u3046\u306a\u308b\u306e\u304b https://t.co/G5j1LupKKR", "source": "<a href=\"http://twittbot.net/\" rel=\"nofollow\">twittbot.net</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 836477374350839808, "id_str": "836477374350839808", "name": "\u2665\u2661\u2665\u751f\u99d2\u91cc\u5948\u2661\u2665\u2661", "screen_name": "merchant32skill", "location": null, "url": null, "description": "\u751f\u99d2\u91cc\u5948\u30d5\u30a1\u30f3\u306b\u306a\u3063\u3066\uff14\u5e74\u3067\u3059(^_\u2212)\u2212\u2606   \u4eca\u304a\u53cb\u9054\u52df\u96c6\u4e2d\u306a\u306e\u3067DM\u304a\u5f85\u3061\u3057\u3066\u307e\u30fc\u3059(*\uff9f\u25bd\uff9f*) \u3061\u306a\u307f\u306b\u6771\u4eac\u306e\u5973\u5b50\u5927\u306b\u901a\u3063\u3066\u307e\u3059\u2661", "translator_type": "none", "protected": false, "verified": false, "followers_count": 80, "friends_count": 114, "listed_count": 1, "favourites_count": 0, "statuses_count": 16170, "created_at": "Tue Feb 28 07:25:21 +0000 2017", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "ja", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/836477802434060288/uubtTFN-_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/836477802434060288/uubtTFN-_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/836477374350839808/1488266840", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [{"url": "https://t.co/G5j1LupKKR", "expanded_url": "https://goo.gl/zH55rD", "display_url": "goo.gl/zH55rD", "indices": [26, 49]}], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "possibly_sensitive": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1525467097666"}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060053934080, "id_str": "992507060053934080", "text": "@SteffenPloeger @G_Smitherman #sorry. Thank you for signing up as a member. As a member, you get a ranked ballot to\u2026 https://t.co/v5UeFjeVAT", "display_text_range": [30, 140], "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": true, "in_reply_to_status_id": 992502441655480320, "in_reply_to_status_id_str": "992502441655480320", "in_reply_to_user_id": 63179868, "in_reply_to_user_id_str": "63179868", "in_reply_to_screen_name": "SteffenPloeger", "user": {"id": 16267310, "id_str": "16267310", "name": "Todd Ross", "screen_name": "tejross", "location": "Toronto", "url": "http://www.toddross.ca", "description": "Seeking the Ontario liberal nomination in Toronto Centre. @ToYorkMetis Chair, LGBT Purge Lead Plaintiff, #Toronto #torcen #onpoli", "translator_type": "none", "protected": false, "verified": false, "followers_count": 2420, "friends_count": 2608, "listed_count": 66, "favourites_count": 3482, "statuses_count": 8708, "created_at": "Sat Sep 13 02:12:08 +0000 2008", "utc_offset": -18000, "time_zone": "Quito", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/378800000106614129/24c4ed5d72a85e871f51649ddd5bc873_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000106614129/24c4ed5d72a85e871f51649ddd5bc873_normal.jpeg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/16267310/1523206186", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "extended_tweet": {"full_text": "@SteffenPloeger @G_Smitherman #sorry. Thank you for signing up as a member. As a member, you get a ranked ballot tomorrow and I'm doing my job to make sure you know about my 25 years in the community and my reason for running.", "display_text_range": [30, 226], "entities": {"hashtags": [{"text": "sorry", "indices": [30, 36]}], "urls": [], "user_mentions": [{"screen_name": "SteffenPloeger", "name": "Steffen Ploeger", "id": 63179868, "id_str": "63179868", "indices": [0, 15]}, {"screen_name": "G_Smitherman", "name": "George Smitherman", "id": 88476286, "id_str": "88476286", "indices": [16, 29]}], "symbols": []}}, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [{"text": "sorry", "indices": [30, 36]}], "urls": [{"url": "https://t.co/v5UeFjeVAT", "expanded_url": "https://twitter.com/i/web/status/992507060053934080", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}], "user_mentions": [{"screen_name": "SteffenPloeger", "name": "Steffen Ploeger", "id": 63179868, "id_str": "63179868", "indices": [0, 15]}, {"screen_name": "G_Smitherman", "name": "George Smitherman", "id": 88476286, "id_str": "88476286", "indices": [16, 29]}], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "en", "timestamp_ms": "1525467097663"}
# {"delete": {"status": {"id": 854412339713642498, "id_str": "854412339713642498", "user_id": 2494258928, "user_id_str": "2494258928"}, "timestamp_ms": "1525467097751"}}
# {"created_at": "Fri May 04 20:51:37 +0000 2018", "id": 992507060037222400, "id_str": "992507060037222400", "text": "RT @Atlanta_Police: JOIN US: Come learn all about APD by joining our Citizens Police Academy Class 32! Next class session starts Tues. May\u2026", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 897617168967372801, "id_str": "897617168967372801", "name": "braggingdragon02", "screen_name": "braggingdragon1", "location": null, "url": null, "description": null, "translator_type": "none", "protected": false, "verified": false, "followers_count": 167, "friends_count": 65, "listed_count": 4, "favourites_count": 8155, "statuses_count": 46049, "created_at": "Wed Aug 16 00:33:04 +0000 2017", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 20:09:39 +0000 2018", "id": 992496499639685120, "id_str": "992496499639685120", "text": "JOIN US: Come learn all about APD by joining our Citizens Police Academy Class 32! Next class session starts Tues.\u2026 https://t.co/rbDXUDrCqu", "display_text_range": [0, 140], "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": true, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 126371589, "id_str": "126371589", "name": "Atlanta Police Dept", "screen_name": "Atlanta_Police", "location": "Atlanta Georgia", "url": "http://www.atlantapd.org", "description": "Official Twitter page of APD - emergencies call 911 - non-emergencies call 311, @APDTraffic for the latest accident info \ud83d\ude94", "translator_type": "none", "protected": false, "verified": true, "followers_count": 36059, "friends_count": 1068, "listed_count": 601, "favourites_count": 1824, "statuses_count": 16206, "created_at": "Thu Mar 25 17:12:30 +0000 2010", "utc_offset": -14400, "time_zone": "Eastern Time (US & Canada)", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000063115837/3e0c3b5a0846e54e1626ccf7bf5c5b46.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000063115837/3e0c3b5a0846e54e1626ccf7bf5c5b46.jpeg", "profile_background_tile": false, "profile_link_color": "003366", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/842018165697703941/5ySASVMy_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/842018165697703941/5ySASVMy_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/126371589/1513968356", "default_profile": false, "default_profi ...
# ...
# {"delete": {"status": {"id": 620968644986671104, "id_str": "620968644986671104", "user_id": 431293667, "user_id_str": "431293667"}, "timestamp_ms": "1525467100984"}}
# {"created_at": "Fri May 04 20:51:40 +0000 2018", "id": 992507072649617409, "id_str": "992507072649617409", "text": "RT @ufltm: Change \u2013 @BTS_twt RM, Wale #RoarForChange \nhttps://t.co/tgJtnP1Ifw", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 3190473817, "id_str": "3190473817", "name": "Blackhearedjoon.", "screen_name": "Ssasha1342", "location": "tengohambrelandia(? ", "url": null, "description": "I finally get my hixtape \ud83d\udc95\n(beardjoon)", "translator_type": "none", "protected": false, "verified": false, "followers_count": 277, "friends_count": 417, "listed_count": 1, "favourites_count": 26478, "statuses_count": 8629, "created_at": "Sun May 10 04:59:25 +0000 2015", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "es", "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/986988244398166016/xF9HfxBx_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/986988244398166016/xF9HfxBx_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/3190473817/1522727373", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 20:50:42 +0000 2018", "id": 992506827832164353, "id_str": "992506827832164353", "text": "Change \u2013 @BTS_twt RM, Wale #RoarForChange \nhttps://t.co/tgJtnP1Ifw", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 950886026142191616, "id_str": "950886026142191616", "name": "ri \u8f49 | #FakeLove", "screen_name": "ufltm", "location": "notifs: off || DON'T FOLLOW", "url": "https://amzn.to/2H8DhvT", "description": "Pre-order 'LOVE YOURSELF \u8f49 Tear' below for concert ticket luck \u2661", "translator_type": "none", "protected": false, "verified": false, "followers_count": 4, "friends_count": 57, "listed_count": 0, "favourites_count": 2464, "statuses_count": 5728, "created_at": "Wed Jan 10 00:24:30 +0000 2018", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/991783923301650432/0JIGz4sV_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/991783923301650432/0JIGz4sV_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/950886026142191616/1525295129", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote ...
# {"delete": {"status": {"id": 620967894218883076, "id_str": "620967894218883076", "user_id": 146906983, "user_id_str": "146906983"}, "timestamp_ms": "1525467100984"}}
# {"delete": {"status": {"id": 620972369528557568, "id_str": "620972369528557568", "user_id": 342204293, "user_id_str": "342204293"}, "timestamp_ms": "1525467101025"}}
# {"delete": {"status": {"id": 620974533793742850, "id_str": "620974533793742850", "user_id": 579262129, "user_id_str": "579262129"}, "timestamp_ms": "1525467101057"}}
# {"delete": {"status": {"id": 620975779489427456, "id_str": "620975779489427456", "user_id": 3372820282, "user_id_str": "3372820282"}, "timestamp_ms": "1525467101094"}}
# {"delete": {"status": {"id": 620983400552251392, "id_str": "620983400552251392", "user_id": 2949532947, "user_id_str": "2949532947"}, "timestamp_ms": "1525467101208"}}
# {"delete": {"status": {"id": 620989545186725888, "id_str": "620989545186725888", "user_id": 355587148, "user_id_str": "355587148"}, "timestamp_ms": "1525467101278"}}
# {"delete": {"status": {"id": 620439994897944576, "id_str": "620439994897944576", "user_id": 2899662239, "user_id_str": "2899662239"}, "timestamp_ms": "1525467101276"}}
# {"delete": {"status": {"id": 620988421134282752, "id_str": "620988421134282752", "user_id": 1732271450, "user_id_str": "1732271450"}, "timestamp_ms": "1525467101267"}}
# {"delete": {"status": {"id": 788923588581679109, "id_str": "788923588581679109", "user_id": 1919072137, "user_id_str": "1919072137"}, "timestamp_ms": "1525467101278"}}
# {"created_at": "Fri May 04 20:51:40 +0000 2018", "id": 992507072628469760, "id_str": "992507072628469760", "text": "\u751f\u304d\u3066\u6b32\u3057\u3044 https://t.co/ovm0BlINif", "display_text_range": [0, 6], "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 971731824148824064, "id_str": "971731824148824064", "name": "\u67af\u308c\u679d", "screen_name": "neet_eda", "location": "\u795e\u5948\u5ddd\u2192\u9e7f\u5150\u5cf6", "url": "https://ameblo.jp/kaleta", "description": "\u72ed\u304f\u6d45\u3044\u7d20\u4eba\u540c\u5b9a\u30ac\u30b5\u30ea\u30b9\u30c8\u3002\u63a1\u96c6\u304c\u597d\u304d\u3002", "translator_type": "none", "protected": false, "verified": false, "followers_count": 244, "friends_count": 257, "listed_count": 1, "favourites_count": 1134, "statuses_count": 654, "created_at": "Thu Mar 08 12:58:15 +0000 2018", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/971757053784899584/ZZ0H3Jn1_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/971757053784899584/ZZ0H3Jn1_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/971731824148824064/1521645967", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": [], "media": [{"id": 992507057835200512, "id_str": "992507057835200512", "indices": [7, 30], "media_url": "http://pbs.twimg.com/media/DcYX6RtV0AACtU1.jpg", "media_url_https": "https://pbs.twimg.com/media/DcYX6RtV0AACtU1.jpg", "url": "https://t.co/ovm0BlINif", "display_url": "pic.twitter.com/ovm0BlINif", "expanded_url": "https://twitter.com/neet_eda/status/992507072628469760/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "large": {"w": 2048, "h": 1536, "resize": "fit"}, "medium": {"w": 1200, "h": 900, "resize": "fit"}, "small": {"w": 680, "h": 510, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 992507057835200512, "id_str": "992507057835200512", "indices": [7, 30], "media_url": "http://pbs.twimg.com/media/DcYX6RtV0AACtU1.jpg", "media_url_https": "https://pbs.twimg.com/media/DcYX6RtV0AACtU1.jpg", "url": "https://t.co/ovm0BlINif", "display_url": "pic.twitter.com/ovm0BlINif", "expanded_url": "https://twitter.com/neet_eda/status/992507072628469760/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "large": {"w": 2048, "h": 1536, "resize": "fit"}, "medium": {"w": 1200, "h": 900, "resize": "fit"}, "small": {"w": 680, "h": 510, "resize": "fit"}}}]}, "favorited": false, "retweeted": false, "possibly_sensitive": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1525467100661"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-9bb9add3695e> in <module>()
# ----> 1 for line in api.GetStreamSample():
#       2     print(json.dumps(line))
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/twitter/api.py in GetStreamSample(self, delimited, stall_warnings)
#    4511         }
#    4512         resp = self._RequestStream(url, 'GET', data=parameters)
# -> 4513         for line in resp.iter_lines():
#    4514             if line:
#    4515                 data = self._ParseAndCheckTwitter(line.decode('utf-8'))
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     787         pending = None
#     788
# --> 789         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     790
#     791             if pending is not None:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %% [markdown]
# Or track the tweets where specific users have been tagged!

# %%
USERS = ['@twitter',
         '@twitterapi',
         '@support']
for line in api.GetStreamFilter(track=USERS):
    print(json.dumps(line))
# Out:
# {"created_at": "Fri May 04 20:52:18 +0000 2018", "id": 992507231265374208, "id_str": "992507231265374208", "text": "@DanMarrazza Get in touch with Josh Brolin.  He's currently holding the Time Stone.  He can reverse this in a coupl\u2026 https://t.co/BrNcLChgDW", "display_text_range": [13, 140], "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": true, "in_reply_to_status_id": 992438990098677760, "in_reply_to_status_id_str": "992438990098677760", "in_reply_to_user_id": 338047783, "in_reply_to_user_id_str": "338047783", "in_reply_to_screen_name": "DanMarrazza", "user": {"id": 3113334406, "id_str": "3113334406", "name": "50investors.com", "screen_name": "50investors", "location": "Las Vegas, Nevada", "url": "http://www.50investors.com", "description": "http://50investors.com is live as of 5/1/2015!  Mission Statement:  To Find Value, To Provide Value.  Please visit our site!", "translator_type": "none", "protected": false, "verified": false, "followers_count": 228, "friends_count": 120, "listed_count": 14, "favourites_count": 1418, "statuses_count": 4618, "created_at": "Wed Mar 25 05:47:17 +0000 2015", "utc_offset": null, "time_zone": null, "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "355E3B", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/984181384376762368/BrlqnGMy_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/984181384376762368/BrlqnGMy_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/3113334406/1523482062", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "extended_tweet": {"full_text": "@DanMarrazza Get in touch with Josh Brolin.  He's currently holding the Time Stone.  He can reverse this in a couple of seconds.  If you can't get in touch with Josh on @Twitter?  Ask @VancityReynolds to reach out to his buddy Cable/Thanos.  Whatever he is in the MCU... https://t.co/lP8gWECaTx", "display_text_range": [13, 270], "entities": {"hashtags": [], "urls": [], "user_mentions": [{"screen_name": "DanMarrazza", "name": "Dan Marrazza", "id": 338047783, "id_str": "338047783", "indices": [0, 12]}, {"screen_name": "Twitter", "name": "Twitter", "id": 783214, "id_str": "783214", "indices": [169, 177]}, {"screen_name": "VancityReynolds", "name": "Ryan Reynolds", "id": 2893511188, "id_str": "2893511188", "indices": [184, 200]}], "symbols": [], "media": [{"id": 992507118354812929, "id_str": "992507118354812929", "indices": [271, 294], "media_url": "http://pbs.twimg.com/media/DcYX9zKV0AEq7mL.jpg", "media_url_https": "https://pbs.twimg.com/media/DcYX9zKV0AEq7mL.jpg", "url": "https://t.co/lP8gWECaTx", "display_url": "pic.twitter.com/lP8gWECaTx", "expanded_url": "https://twitter.com/50investors/status/992507231265374208/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "small": {"w": 680, "h": 357, "resize": "fit"}, "medium": {"w": 764, "h": 401, "resize": "fit"}, "large": {"w": 764, "h": 401, "resize": "fit"}}}, {"id": 992507180141002752, "id_str": "992507180141002752", "indices": [271, 294], "media_url": "http://pbs.twimg.com/media/DcYYBZVUQAAZEmZ.jpg", "media_url_https": "https://pbs.twimg.com/media/DcYYBZVUQAAZEmZ.jpg", "url": "https://t.co/lP8gWECaTx", "display_url": "pic.twitter.com/lP8gWECaTx", "expanded_url": "https://twitter.com/50investors/status/9925072312653 ...
# {"created_at": "Fri May 04 20:52:20 +0000 2018", "id": 992507238802706432, "id_str": "992507238802706432", "text": "RT @fscarfe: @JeriLowrance @AntwanTurman @XandraXandraBX @SelectiveRecord @soberality @CalibreRadioSC @QwaaTm @CalibreClothing @CalibreGeni\u2026", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 165776306, "id_str": "165776306", "name": "Vett41", "screen_name": "vett41", "location": "North Little Rock, AR", "url": null, "description": "follow @bananavet501", "translator_type": "none", "protected": false, "verified": false, "followers_count": 7003, "friends_count": 7326, "listed_count": 58, "favourites_count": 89997, "statuses_count": 33846, "created_at": "Mon Jul 12 14:21:59 +0000 2010", "utc_offset": -18000, "time_zone": "Central Time (US & Canada)", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "00B806", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif", "profile_background_tile": false, "profile_link_color": "00B81C", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/945428913530068992/5f1008W4_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/945428913530068992/5f1008W4_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/165776306/1515247702", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri May 04 01:30:05 +0000 2018", "id": 992214749826830336, "id_str": "992214749826830336", "text": "@JeriLowrance @AntwanTurman @XandraXandraBX @SelectiveRecord @soberality @CalibreRadioSC @QwaaTm @CalibreClothing\u2026 https://t.co/Zq49vzYxZU", "display_text_range": [117, 140], "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": true, "in_reply_to_status_id": 992138912679182336, "in_reply_to_status_id_str": "992138912679182336", "in_reply_to_user_id": 405259565, "in_reply_to_user_id_str": "405259565", "in_reply_to_screen_name": "fscarfe", "user": {"id": 405259565, "id_str": "405259565", "name": "fred scarfe", "screen_name": "fscarfe", "location": "Greater Vancouver", "url": null, "description": "JMF Research BC-Specializing in Alcohol ,Community Public Health and Safety advocate Retired Fire Chief,Musician(Keyboard Player)etc.", "translator_type": "none", "protected": false, "verified": false, "followers_count": 8971, "friends_count": 6305, "listed_count": 81, "favourites_count": 125060, "statuses_count": 139125, "created_at": "Sat Nov 05 02:21:51 +0000 2011", "utc_offset": null, "time_zone": null, "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "981CEB", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/695443751439724544/w1djJoIT_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/695443751439724544/w1djJoIT_normal.jpg", "profile_banner_url": "https://pbs.tw ...
# {"created_at": "Fri May 04 20:52:20 +0000 2018", "id": 992507241076084738, "id_str": "992507241076084738", "text": "@TwitterMusic @Twitter @diplo @Labrinth @Sia @RaeSremmurd @ShawnMendes @thegreatkhalid @troyesivan @xtina\u2026 https://t.co/l5XU7YxUuk", "display_text_range": [117, 140], "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": true, "in_reply_to_status_id": 992388373070270464, "in_reply_to_status_id_str": "992388373070270464", "in_reply_to_user_id": 373471064, "in_reply_to_user_id_str": "373471064", "in_reply_to_screen_name": "TwitterMusic", "user": {"id": 728652330, "id_str": "728652330", "name": "Tabark", "screen_name": "zaynlovesziam", "location": "Dubai - Istanbul", "url": "https://curiouscat.me/SmileMyZiamx", "description": "18. Liam&Zayn. #OTRADubai.", "translator_type": "regular", "protected": false, "verified": false, "followers_count": 1787, "friends_count": 176, "listed_count": 38, "favourites_count": 2326, "statuses_count": 80003, "created_at": "Tue Jul 31 15:42:48 +0000 2012", "utc_offset": 10800, "time_zone": "Istanbul", "geo_enabled": true, "lang": "en", "contributors_enabled": false, "is_translator": false, "profile_background_color": "ABB8C2", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif", "profile_background_tile": false, "profile_link_color": "ABB8C2", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "F6F6F6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/991663865678254080/0oFLYV_X_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/991663865678254080/0oFLYV_X_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/728652330/1524237048", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "extended_tweet": {"full_text": "@TwitterMusic @Twitter @diplo @Labrinth @Sia @RaeSremmurd @ShawnMendes @thegreatkhalid @troyesivan @xtina @tydollasign @2chainz #Familiar by @LiamPayne @JBALVIN", "display_text_range": [128, 160], "entities": {"hashtags": [{"text": "Familiar", "indices": [128, 137]}], "urls": [], "user_mentions": [{"screen_name": "TwitterMusic", "name": "Twitter Music", "id": 373471064, "id_str": "373471064", "indices": [0, 13]}, {"screen_name": "Twitter", "name": "Twitter", "id": 783214, "id_str": "783214", "indices": [14, 22]}, {"screen_name": "diplo", "name": "diplo", "id": 17174309, "id_str": "17174309", "indices": [23, 29]}, {"screen_name": "Labrinth", "name": "Labrinth", "id": 97837399, "id_str": "97837399", "indices": [30, 39]}, {"screen_name": "Sia", "name": "sia", "id": 23497233, "id_str": "23497233", "indices": [40, 44]}, {"screen_name": "RaeSremmurd", "name": "Rae Sremmurd", "id": 2236633914, "id_str": "2236633914", "indices": [45, 57]}, {"screen_name": "ShawnMendes", "name": "Shawn Mendes", "id": 379408088, "id_str": "379408088", "indices": [58, 70]}, {"screen_name": "thegreatkhalid", "name": "Khalid", "id": 1852644804, "id_str": "1852644804", "indices": [71, 86]}, {"screen_name": "troyesivan", "name": "troye sivan", "id": 53338746, "id_str": "53338746", "indices": [87, 98]}, {"screen_name": "xtina", "name": "Christina Aguilera", "id": 268439864, "id_str": "268439864", "indices": [99, 105]}, {"screen_name": "tydollasign", "name": "Ty Dolla $ign", "id": 25932445, "id_str": "25932445", "indices": [106, 118]}, {"screen_name": "2chainz", "name": "Tity Boi (2 Chainz)", "id": 185487499, "id_str": "185487499", "indices": [119, 127]}, {"screen_name": "LiamPayne", "name": "Liam", "id": 158314798, "id_str": "158314798", "indices": [141, 151]}, {"screen_name": "JBALVIN", "name": "J BALVIN",  ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-16342115fbea> in <module>()
#       2          '@twitterapi',
#       3          '@support']
# ----> 4 for line in api.GetStreamFilter(track=USERS):
#       5     print(json.dumps(line))
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/twitter/api.py in GetStreamFilter(self, follow, track, locations, languages, delimited, stall_warnings, filter_level)
#    4569
#    4570         resp = self._RequestStream(url, 'POST', data=data)
# -> 4571         for line in resp.iter_lines():
#    4572             if line:
#    4573                 data = self._ParseAndCheckTwitter(line.decode('utf-8'))
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     787         pending = None
#     788
# --> 789         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     790
#     791             if pending is not None:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/wesleybeckner/anaconda/envs/py36/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %% [markdown]
# Exciting possibilities. After training a CNN on climate data, we may be able to track sentiment based on whatever demographics we choose!
